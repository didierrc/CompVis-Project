# %% [markdown]
# # CV Course Project: Assignment - Image Recognition
#
# ---
#
# **Group:**
# - Alumno 1: San Millan Rodrigues, Nadine (n.srodrigues@alumnos.upm.es)
# - Alumno 2: Sukhorukova, Anastasia (anastasia.s@alumnos.upm.es)
# - Alumno 3: Reyes Castro, Didier Yamil (didier.reyes.castro@alumnos.upm.es)
#
# **Course:** Computer Vision (CV) - 2025/26
#
# **Institution:** Polytechnic University of Madrid (UPM)
#
# **Date:** January 2026
#
# ---
#
# ## Goals
#
# The goals of the assignment are:
# * Develop proficiency in using Tensorflow/Keras for training Neural Nets (NNs).
# * Put into practice the acquired knowledge to optimize the parameters and architecture of a feedforward Neural Net (ffNN), in the context of an image recognition problem.
# * Put into practice NNs specially conceived for analysing images. Design and optimize the parameters of a Convolutional Neural Net (CNN) to deal with previous task.
# * Train popular architectures from scratch (e.g., GoogLeNet, VGG, ResNet, ...), and compare the results with the ones provided by their pre-trained versions using transfer learning.
#
# Follow the link below to download the classification data set  “xview_recognition”: [https://drive.upm.es/s/2DDPE2zHw5dbM3G](https://drive.upm.es/s/2DDPE2zHw5dbM3G)

# %% [markdown]
# ## 0 Setup and Data Loading

# %% [markdown]
# ### 0.1 Install and Import Required Libraries

# %%
# !pip install tensorflow numpy rasterio scikit-learn matplotlib keras
# Out:
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.12/dist-packages (2.19.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (2.0.2)
# Collecting rasterio
#   Downloading rasterio-1.5.0-cp312-cp312-manylinux_2_28_x86_64.whl.metadata (8.6 kB)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.12/dist-packages (1.6.1)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (3.10.0)
# Requirement already satisfied: keras in /usr/local/lib/python3.12/dist-packages (3.10.0)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (25.9.23)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from tensorflow) (25.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (5.29.5)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (2.32.5)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from tensorflow) (75.2.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (3.1.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (4.15.0)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (2.0.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (1.75.1)
# Requirement already satisfied: tensorboard~=2.19.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (2.19.0)
# Requirement already satisfied: h5py>=3.11.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (3.15.1)
# Requirement already satisfied: ml-dtypes<1.0.0,>=0.5.1 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (0.5.3)
# Collecting affine (from rasterio)
#   Downloading affine-2.4.0-py3-none-any.whl.metadata (4.0 kB)
# Requirement already satisfied: attrs in /usr/local/lib/python3.12/dist-packages (from rasterio) (25.4.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from rasterio) (2025.11.12)
# Requirement already satisfied: click!=8.2.*,>=4.0 in /usr/local/lib/python3.12/dist-packages (from rasterio) (8.3.1)
# Requirement already satisfied: cligj>=0.5 in /usr/local/lib/python3.12/dist-packages (from rasterio) (0.7.2)
# Requirement already satisfied: pyparsing in /usr/local/lib/python3.12/dist-packages (from rasterio) (3.2.5)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn) (1.15.3)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (11.3.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: rich in /usr/local/lib/python3.12/dist-packages (from keras) (14.2.0)
# Requirement already satisfied: namex in /usr/local/lib/python3.12/dist-packages (from keras) (0.1.0)
# Requirement already satisfied: optree in /usr/local/lib/python3.12/dist-packages (from keras) (0.17.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from astunparse>=1.6.0->tensorflow) (0.45.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.21.0->tensorflow) (2.6.2)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.12/dist-packages (from tensorboard~=2.19.0->tensorflow) (3.9)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.12/dist-packages (from tensorboard~=2.19.0->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from tensorboard~=2.19.0->tensorflow) (3.1.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich->keras) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich->keras) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich->keras) (0.1.2)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.12/dist-packages (from werkzeug>=1.0.1->tensorboard~=2.19.0->tensorflow) (3.0.3)
# Downloading rasterio-1.5.0-cp312-cp312-manylinux_2_28_x86_64.whl (37.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 37.6/37.6 MB 47.5 MB/s eta 0:00:00:00:0100:01
# Downloading affine-2.4.0-py3-none-any.whl (15 kB)
# Installing collected packages: affine, rasterio
# Successfully installed affine-2.4.0 rasterio-1.5.0

# %% [markdown]
# Loading the necessary libraries.

# %%
# Python libraries
import uuid
import warnings
import json
import os
import math

# External libraries
import numpy as np
import rasterio
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix

import tensorflow as tf
from tensorflow.keras import Input
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten, Activation, Rescaling, BatchNormalization, Dropout, LeakyReLU, Conv2D, MaxPooling2D, RandomFlip, RandomRotation, RandomZoom
from tensorflow.keras.optimizers import Adam, AdamW
from tensorflow.keras.callbacks import TerminateOnNaN, EarlyStopping, ReduceLROnPlateau, ModelCheckpoint
# Out:
# 2026-01-10 23:31:01.206156: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1768087861.405097      55 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1768087861.461038      55 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1768087861.923806      55 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1768087861.923855      55 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1768087861.923858      55 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1768087861.923862      55 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.

# %% [markdown]
# Check if GPU is available for training the models.

# %%
print(tf.config.list_physical_devices('GPU'))
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %% [markdown]
# ### 0.2 Load the Dataset & Image Loader
#
# Before loading the dataset, set the path to the folder containing the images.

# %%
#IMAGES_PATH = '/kaggle/input/xview-dataset/xview_recognition/'
IMAGES_PATH = '/kaggle/input/xview-recognition/'

# %%
class GenericObject:
    """
    Generic object data.
    """
    def __init__(self):
        self.id = uuid.uuid4()
        self.bb = (-1, -1, -1, -1)
        self.category= -1
        self.score = -1

class GenericImage:
    """
    Generic image data.
    """
    def __init__(self, filename):
        self.filename = filename
        self.tile = np.array([-1, -1, -1, -1])  # (pt_x, pt_y, pt_x+width, pt_y+height)
        self.objects = list([])

    def add_object(self, obj: GenericObject):
        self.objects.append(obj)

# %%
categories = {0: 'Cargo plane', 1: 'Small car', 2: 'Bus', 3: 'Truck', 4: 'Motorboat', 5: 'Fishing vessel', 6: 'Dump truck', 7: 'Excavator', 8: 'Building', 9: 'Helipad', 10: 'Storage tank', 11: 'Shipping container', 12: 'Pylon'}

# %%
def load_geoimage(filename):
    warnings.filterwarnings('ignore', category=rasterio.errors.NotGeoreferencedWarning)
    src_raster = rasterio.open(IMAGES_PATH + filename, 'r')
    # RasterIO to OpenCV (see inconsistencies between libjpeg and libjpeg-turbo)
    input_type = src_raster.profile['dtype']
    input_channels = src_raster.count
    img = np.zeros((src_raster.height, src_raster.width, src_raster.count), dtype=input_type)
    for band in range(input_channels):
        img[:, :, band] = src_raster.read(band+1)
    return img

# %%
# Load database
json_file = IMAGES_PATH + 'xview_ann_train.json'
with open(json_file) as ifs:
    json_data = json.load(ifs)
ifs.close()

# %%
counts = dict.fromkeys(categories.values(), 0)
anns_dataset = []
for json_img, json_ann in zip(json_data['images'].values(), json_data['annotations'].values()):
    image = GenericImage(json_img['filename'])
    image.tile = np.array([0, 0, json_img['width'], json_img['height']])
    obj = GenericObject()
    obj.bb = (int(json_ann['bbox'][0]), int(json_ann['bbox'][1]), int(json_ann['bbox'][2]), int(json_ann['bbox'][3]))
    obj.category = json_ann['category_id']
    # Resampling strategy to reduce training time
    counts[obj.category] += 1
    image.add_object(obj)
    anns_dataset.append(image)
print(counts)
# Out:
# {'Cargo plane': 635, 'Small car': 3324, 'Bus': 1768, 'Truck': 2210, 'Motorboat': 1069, 'Fishing vessel': 706, 'Dump truck': 1236, 'Excavator': 789, 'Building': 3594, 'Helipad': 111, 'Storage tank': 1469, 'Shipping container': 1523, 'Pylon': 312}

# %%
def generator_images(objs, batch_size, do_shuffle=False):
    while True:
        if do_shuffle:
            np.random.shuffle(objs)
        groups = [objs[i:i+batch_size] for i in range(0, len(objs), batch_size)]
        for group in groups:
            images, labels = [], []
            for (filename, obj) in group:
                # Load image
                images.append(load_geoimage(filename))
                probabilities = np.zeros(len(categories))
                probabilities[list(categories.values()).index(obj.category)] = 1
                labels.append(probabilities)
            images = np.array(images).astype(np.float32)
            labels = np.array(labels).astype(np.float32)
            yield images, labels

# %% [markdown]
# ### 0.3 Setup

# %%
# Fix random seed for reproducibility
RANDOM_SEED = 42
def set_seed(seed_value):
    np.random.seed(seed_value)
    tf.random.set_seed(seed_value)
set_seed(RANDOM_SEED)

# Number of categories for classification
NUM_CATEGORIES = len(categories)

# %% [markdown]
# ## 1 CNN Model
#
# Taking the best ffNN model as a baseline, we designed and trained a Convolutional Neural Network (CNN) to improve the results.
#
# **How to Improve the Model?**
# - Add **Data Augmentation** techniques to increase the diversity of the training data.
# - Include **Dropout Layers** to prevent overfitting and **Batch Normalization** to stabilize and accelerate training.
# - Network Architecture: Experiment with different architectures, such as adding more convolutional layers, changing filter sizes, and adjusting the number of neurons in dense layers.
# - Hyperparameter Tuning: Optimize learning rate, batch size, number of epochs, and optimizer
#
# ---
# ### Log of Changes
#
# - Model 1: Simplification of ffNN architecture to a CNN architecture -> RESULTS: Less training time, better validation accuracy.
#   - 1 Conv2D layer (32 filters, 3x3 kernel) followed by a single Softmax Dense layer (1).
#   - ReLU activation.
#   - Adam optimizer (learning rate: 1e-4).
#   - Epochs: 20
#   - Batch: 16
# - Model 2: FOCUS ON NETWORK ARCHITECTURE
#   - Test 1: 3 Conv2D layers (32, 64, 128 filters; 3x3 kernel) followed by a single Softmax Dense layer. -> RESULTS: Even less training time (1h) but slightly worse validation accuracy. Huge Overfitting (0.99 train acc vs 0.60 val acc).
#   - Test 2: Lets see what happens when Pooling layers are added after each Conv2D layer. --> RESULTS: Highest validation accuracy (0.64) so far, but still overfitting (0.93 train acc vs 0.64 val acc).
#   - Test 3: Lets now try to add more layers in the classifier -> This is a typical CNN architecture like AlexNet --> Results: Slight increase in accuracy (0.6448) but still a huge overftting.
# - Model 3: FOCUS ON REDUCING OVERFITTING
#   - Test 1: Adding BatchNormalisation layers to Feature extraction phase. --> RESULTS: Validation accuracy has decreased to 0.6 again but now it is overfitting less.
#   - Test 2: Addind BatchNorm to Classification phase and adding Dropout layers. --> RESULTS: We have greatly reduced overfitting! (0.8 train vs 0.6 val) but there is room for improvement. We have also increased val accuracy to 0.67 (NEW HIGHEST).
#   - Test 3: Adding DataAugmentation and L2 Regularisation with AdamW optimiser to reduce the variance. --> RESULTS: WE HAVE COMPLETELY REDUCED OVERFITTING (look at loss graph) but val accuracy has dropped to 0.6.
# - Model 4: FOCUS ON INCREASING ACCURACY
#   - Test 1: Train for longer (50 epochs) and increase patience in EarlyStopping (10 to 40) --> RESULTS: val accuracy increased to 0.693 (NEW HIGHEST).
#   - Test 2: Adding padding to Conv2D layers to preserve spatial dimensions. --> RESULTS: val accuracy decreased a bit to 0.6928 but still good. Increassed a bit Recall and Precision.
#   - Test 3: Increasing the number of filters in Conv2D layers (64, 128, 256) --> RESULTS: val accuracy increased again to 0.69973 (NEW HIGHEST). Increased Precision, reduced Recall.
#   - Test 4: Adding a new dense layer in the classifier with 256 neurons --> RESULTS: val accuracy increased again to 0.7152 (NEW HIGHEST). Increased Recall, similar Precision.
#   - Test 4_Focal: Introduced Focal Loss but not so much of a change. Less val accuracy, recall and precision but Helipad 100% accuracy f.i.
#   - Test 4_Dropout: Reduced dropout in Conv layers and increased in Dense layers. --> RESULTS: Starting to underfit.
#   - Test 5: Changed MaxPooling layers to strides in Conv2D layers and reduced Dropout in Dense Layers --> RESULTS: Increased val accuracy to 0.7178 (NEW HIGHEST). Reduced 1% recall but increased precision by 3%.
#   - Test 6: Increase Conv2D layers (16 and 512) and number of epochs (70) --> RESULTS: Increased val accuracy to 0.777 (NEW HIGHEST).

# %% [markdown]
# ### 1.1 Setup

# %%
train2, val2 = train_test_split(anns_dataset,
                                test_size=0.1, 
                                random_state=RANDOM_SEED, 
                                stratify=[obj.category for ann in anns_dataset for obj in ann.objects])
print('Number of training images: ' + str(len(train2)))
print('Number of validation images: ' + str(len(val2)))
# Out:
# Number of training images: 16871
# Number of validation images: 1875

# %%
print('Compiling the model...')


model = Sequential([
    Input(shape=(224, 224, 3)), # 224x224 images with 3 channels (RGB)
    
    # --- Data Augmentation Layers ---
    RandomFlip("horizontal"),
    RandomRotation(0.1),  # Randomly rotate by up to 10% (36 degrees)
    RandomZoom(0.1),      # Randomly zoom by up to 10%
    # --------------------------------

    Rescaling(1./255), # Rescale pixel values to [0, 1]
    
    # --- Feature extraction ---

    Conv2D(32, (3, 3), padding='same', strides=(2, 2)), # Convolution with 32 filters and 3x3 kernel
    BatchNormalization(),
    Activation('relu'),

    Conv2D(64, (3, 3), padding='same', strides=(2, 2)), # Convolution with 64 filters and 3x3 kernel
    BatchNormalization(),
    Activation('relu'),

    Conv2D(128, (3, 3), padding='same', strides=(2, 2)), # Convolution with 128 filters and 3x3 kernel
    BatchNormalization(),
    Activation('relu'),
    
    Conv2D(256, (3, 3), padding='same', strides=(2, 2)), # Convolution with 256 filters and 3x3 kernel
    BatchNormalization(),
    Activation('relu'),

    Conv2D(512, (3, 3), padding='same', strides=(2, 2)), # Convolution with 512 filters and 3x3 kernel
    BatchNormalization(),
    Activation('relu'),
    
    # --- Classification ---
    Flatten(),

    Dense(256), # Fully connected layer with 256 units
    BatchNormalization(),
    Activation('relu'),
    Dropout(0.3),

    Dense(128), # Fully connected layer with 128 units
    BatchNormalization(),
    Activation('relu'),
    Dropout(0.3),

    Dense(NUM_CATEGORIES, activation='softmax') # Output layer with softmax activation
])

model.summary()


opt =  AdamW(learning_rate=1e-4, weight_decay=1e-5)
model.compile(optimizer=opt, loss='categorical_crossentropy', metrics=['accuracy'])
# Out:
# Compiling the model...
# I0000 00:00:1768087945.866954      55 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 15513 MB memory:  -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ random_flip (RandomFlip)        │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ random_rotation                 │ (None, 224, 224, 3)    │             0 │
# │ (RandomRotation)                │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ random_zoom (RandomZoom)        │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ rescaling (Rescaling)           │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d (Conv2D)                 │ (None, 112, 112, 32)   │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 112, 112, 32)   │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation (Activation)         │ (None, 112, 112, 32)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 56, 56, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 56, 56, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_1 (Activation)       │ (None, 56, 56, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 28, 28, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 28, 28, 128)    │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_2 (Activation)       │ (None, 28, 28, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_3 (Conv2D)               │ (None, 14, 14, 256)    │       295,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_3           │ (None, 14, 14, 256)    │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_3 (Activation)       │ (None, 14, 14, 256)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_4 (Conv2D)               │ (None, 7, 7, 512)      │     1,180,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_4           │ (None, 7, 7, 512)      │         2,048 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_4 (Activation)       │ (None, 7, 7, 512)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 25088)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 256)            │     6,422,784 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_5           │ (None, 256)            │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_5 (Activation)       │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 128)            │        32,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_6           │ (None, 128)            │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_6 (Activation)       │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 13)             │         1,677 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 8,031,437 (30.64 MB)
#  Trainable params: 8,028,685 (30.63 MB)
#  Non-trainable params: 2,752 (10.75 KB)

# %%
# Callbacks
MODEL_NAME = 'CNN_model.keras'

model_checkpoint = ModelCheckpoint(MODEL_NAME, monitor='val_accuracy', verbose=1, save_best_only=True)
reduce_lr = ReduceLROnPlateau(monitor='val_accuracy', factor=0.1, patience=10, verbose=1)
early_stop = EarlyStopping(monitor='val_accuracy', patience=40, verbose=1)
terminate = TerminateOnNaN()
callbacks = [model_checkpoint, reduce_lr, early_stop, terminate]

# %%
# Generate the list of objects from annotations
objs_train = [(ann.filename, obj) for ann in train2 for obj in ann.objects]
objs_valid = [(ann.filename, obj) for ann in val2 for obj in ann.objects]

# Generators
BATCH_SIZE = 16
train_generator = generator_images(objs_train, BATCH_SIZE, do_shuffle=True)
valid_generator = generator_images(objs_valid, BATCH_SIZE, do_shuffle=False)

# %% [markdown]
# ### 1.2 Training

# %%
print('Training model...')

EPOCHS = 70
train_steps = math.ceil(len(objs_train)/BATCH_SIZE)
valid_steps = math.ceil(len(objs_valid)/BATCH_SIZE)

h1 = model.fit(train_generator, 
              steps_per_epoch=train_steps, 
              validation_data=valid_generator, 
              validation_steps=valid_steps, 
              epochs=EPOCHS, 
              callbacks=callbacks, 
              verbose=1)

# Best validation model
best_idx = int(np.argmax(h1.history['val_accuracy']))
best_value = np.max(h1.history['val_accuracy'])
print('Best validation model: epoch ' + str(best_idx+1), ' - val_accuracy ' + str(best_value))
# Out:
# Training model...
# Epoch 1/70
# I0000 00:00:1768087968.672947     132 cuda_dnn.cc:529] Loaded cuDNN version 91002
# 1055/1055 ━━━━━━━━━━━━━━━━━━━━ 0s 436ms/step - accuracy: 0.2490 - loss: 2.3716
# Epoch 1: val_accuracy improved from -inf to 0.44640, saving model to CNN_model.keras
# 1055/1055 ━━━━━━━━━━━━━━━━━━━━ 522s 488ms/step - accuracy: 0.2490 - loss: 2.3714 - val_accuracy: 0.4464 - val_loss: 1.6844 - learning_rate: 1.0000e-04
# Epoch 2/70
# 1054/1055 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.4100 - loss: 1.7909
# Epoch 2: val_accuracy improved from 0.44640 to 0.51040, saving model to CNN_model.keras
# 1055/1055 ━━━━━━━━━━━━━━━━━━━━ 63s 60ms/step - accuracy: 0.4100 - loss: 1.7908 - val_accuracy: 0.5104 - val_loss: 1.4197 - learning_rate: 1.0000e-04
# Epoch 3/70
# 1054/1055 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.4662 - loss: 1.5966
# Epoch 3: val_accuracy improved from 0.51040 to 0.55360, saving model to CNN_model.keras
# 1055/1055 ━━━━━━━━━━━━━━━━━━━━ 64s 61ms/step - accuracy: 0.4662 - loss: 1.5965 - val_accuracy: 0.5536 - val_loss: 1.3491 - learning_rate: 1.0000e-04
# Epoch 4/70
# 1054/1055 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.5078 - loss: 1.4788
# Epoch 4: val_accuracy improved from 0.55360 to 0.60587, saving model to CNN_model.keras
# 1055/1055 ━━━━━━━━━━━━━━━━━━━━ 63s 60ms/step - accuracy: 0.5078 - loss: 1.4788 - val_accuracy: 0.6059 - val_loss: 1.2038 - learning_rate: 1.0000e-04
# Epoch 5/70
# 1054/1055 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.5359 - loss: 1.3807
# Epoch 5: val_accuracy improved from 0.60587 to 0.62507, saving model to CNN_model.keras
# 1055/1055 ━━━━━━━━━━━━━━━━━━━━ 64s 61ms/step - accuracy: 0.5359 - loss: 1.3807 - val_accuracy: 0.6251 - val_loss: 1.1445 - learning_rate: 1.0000e-04
# Epoch 6/70
# 1054/1055 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.5496 - loss: 1.3370
# Epoch 6: val_accuracy improved from 0.62507 to 0.63200, saving model to CNN_model.keras
# 1055/1055 ━━━━━━━━━━━━━━━━━━━━ 63s 60ms/step - accuracy: 0.5496 - loss: 1.3370 - val_accuracy: 0.6320 - val_loss: 1.1142 - learning_rate: 1.0000e-04
# Epoch 7/70
# 1054/1055 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.5603 - loss: 1.2909
# Epoch 7: val_accuracy did not improve from 0.63200
# 1055/1055 ━━━━━━━━━━━━━━━━━━━━ 63s 59ms/step - accuracy: 0.5603 - loss: 1.2909 - val_accuracy: 0.6059 - val_loss: 1.1297 - learning_rate: 1.0000e-04
# Epoch 8/70
# 1054/1055 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.5745 - loss: 1.2641
# Epoch 8: val_accuracy did not improve from 0.63200
# 1055/1055 ━━━━━━━━━━━━━━━━━━━━ 60s 57ms/step - accuracy: 0.5745 - loss: 1.2641 - val_accuracy: 0.6176 - val_loss: 1.1004 - learning_rate: 1.0000e-04
# Epoch 9/70
# 1054/1055 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.5912 - loss: 1.2158
# Epoch 9: val_accuracy improved from 0.63200 to 0.67253, saving model to CNN_model.keras
# 1055/1055 ━━━━━━━━━━━━━━━━━━━━ 61s 58ms/step - accuracy: 0.5912 - loss: 1.2158 - val_accuracy: 0.6725 - val_loss: 1.0030 - learning_rate: 1.0000e-04
# Epoch 10/70
# 1054/1055 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.6006 - loss: 1.1866
# Epoch 10: val_accuracy did not improve from 0.67253
# 1055/1055 ━━━━━━━━━━━━━━━━━━━━ 61s 58ms/step - accuracy: 0.6006 - loss: 1.1866 - val_accuracy: 0.6629 - val_loss: 1.0267 - learning_rate: 1.0000e-04
# Epoch 11/70
# 1054/1055 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.5975 - loss: 1.1818
# Epoch 11: val_accuracy did not improve from 0.67253
# 1055/1055 ━━━━━━━━━━━━━━━━━━━━ 64s 61ms/step - accuracy: 0.5975 - loss: 1.1818 - val_accuracy: 0.6672 - val_loss: 1.0121 - learning_rate: 1.0000e-04
# Epoch 12/70
# 1054/1055 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.6072 - loss: 1.1555
# Epoch 12: val_accuracy did not improve from 0.67253
# 1055/1055 ━━━━━━━━━━━━━━━━━━━━ 63s 60ms/step - accuracy: 0.6072 - loss: 1.1555 - val_accuracy: 0.6560 - val_loss: 0.9998 - learning_rate: 1.0000e-04
# Epoch 13/70
# 1054/1055 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.6235 - loss: 1.1245
# Epoch 13: val_accuracy improved from 0.67253 to 0.69227, saving model to CNN_model.keras
# 1055/1055 ━━━━━━━━━━━━━━━━━━━━ 63s 60ms/step - accuracy: 0.6235 - loss: 1.1245 - val_accuracy: 0.6923 - val_loss: 0.9467 - learning_rate: 1.0000e-04
# Epoch 14/70
# 1054/1055 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.6316 - loss: 1.0963
# Epoch 14: val_accuracy did not improve from 0.69227
# 1055/1055 ━━━━━━━━━━━━━━━━━━━━ 61s 58ms/step - accuracy: 0.6315 - loss: 1.0964 - val_accuracy: 0.6768 - val_loss: 0.9770 - learning_rate: 1.0000e-04
# Epoch 15/70
# 1054/1055 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.6401 - loss: 1.0678
# Epoch 15: val_accuracy did not improve from 0.69227
# 1055/1055 ━━━━━━━━━━━━━━━━━━━━ 61s 58ms/step - accuracy: 0.6401 - loss: 1.0678 - val_accuracy: 0.6811 - val_loss: 0.9400 - learning_rate: 1.0000e-04
# Epoch 16/70
# 1054/1055 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.6371 - loss: 1.0638
# Epoch 16: val_accuracy improved from 0.69227 to 0.69280, saving model to CNN_model.keras
# 1055/1055 ━━━━━━━━━━━━━━━━━━━━ 61s 58ms/step - accuracy: 0.6371 - loss: 1.0638 - val_accuracy: 0.6928 - val_loss: 0.9111 - learning_rate: 1.0000e-04
# Epoch 17/70
# 1054/1055 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.6497 - loss: 1.0400
# Epoch 17: val_accuracy improved from 0.69280 to 0.69493, saving model to CNN_model.keras
# 1055/1055 ━━━━━━━━━━━━━━━━━━━━ 60s 57ms/step - accuracy: 0.6496 - loss: 1.0400 - val_accuracy: 0.6949 - val_loss: 0.8941 - learning_rate: 1.0000e-04
# Epoch 18/70
# 1054/1055 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.6409 - loss: 1.0436
# Epoch 18: val_accuracy improved from 0.69493 to 0.70133, saving model to CNN_model.keras
# 1055/1055 ━━━━━━━━━━━━━━━━━━━━ 60s 57ms/step - accuracy: 0.6409 - loss: 1.0435 - val_accuracy: 0.7013 - val_loss: 0.8881 - learning_rate: 1.0000e-04
# Epoch 19/70
# 1054/1055 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.6589 - loss: 0.9936
# Epoch 19: val_accuracy did not improve from 0.70133
# 1055/1055 ━━━━━━━━━━━━━━━━━━━━ 59s 56ms/step - accuracy: 0.6589 - loss: 0.9937 - val_accuracy: 0.6981 - val_loss: 0.9019 - learning_rate: 1.0000e-04
# Epoch 20/70
# 1054/1055 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.6550 - loss: 1.0036
# Epoch 20: val_accuracy improved from 0.70133 to 0.70720, saving model to CNN_model.keras
# 1055/1055 ━━━━━━━━━━━━━━━━━━━━ 61s 58ms/step - accuracy: 0.6549 - loss: 1.0037 - val_accuracy: 0.7072 - val_loss: 0.8906 - learning_rate: 1.0000e-04
# Epoch 21/70
# 1054/1055 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.6734 - loss: 0.9652
# Epoch 21: val_accuracy did not improve from 0.70720
# 1055/1055 ━━━━━━━━━━━━━━━━━━━━ 59s 56ms/step - accuracy: 0.6734 - loss: 0.9653 - val_accuracy: 0.6896 - val_loss: 0.9507 - learning_rate: 1.0000e-04
# Epoch 22/70
# 1054/1055 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.6663 - loss: 0.9740
# Epoch 22: val_accuracy did not improve from 0.70720
# 1055/1055 ━━━━━━━━━━━━━━━━━━━━ 60s 56ms/step - accuracy: 0.6663 - loss: 0.9740 - val_accuracy: 0.7013 - val_loss: 0.9030 - learning_rate: 1.0000e-04
# Epoch 23/70
# 1054/1055 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.6772 - loss: 0.9510
# Epoch 23: val_accuracy did not improve from 0.70720
# 1055/1055 ━━━━━━━━━━━━━━━━━━━━ 60s 57ms/step - accuracy: 0.6771 - loss: 0.9510 - val_accuracy: 0.7019 - val_loss: 0.8936 - learning_rate: 1.0000e-04
# Epoch 24/70
# 1054/1055 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.6738 - loss: 0.9494
# Epoch 24: val_accuracy did not improve from 0.70720
# 1055/1055 ━━━━━━━━━━━━━━━━━━━━ 61s 58ms/step - accuracy: 0.6738 - loss: 0.9494 - val_accuracy: 0.6987 - val_loss: 0.8674 - learning_rate: 1.0000e-04
# Epoch 25/70
# 1054/1055 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.6819 - loss: 0.9349
# Epoch 25: val_accuracy improved from 0.70720 to 0.71467, saving model to CNN_model.keras
# 1055/1055 ━━━━━━━━━━━━━━━━━━━━ 61s 58ms/step - accuracy: 0.6819 - loss: 0.9349 - val_accuracy: 0.7147 - val_loss: 0.8508 - learning_rate: 1.0000e-04
# Epoch 26/70
# 1054/1055 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.6798 - loss: 0.9422
# Epoch 26: val_accuracy improved from 0.71467 to 0.71627, saving model to CNN_model.keras
# 1055/1055 ━━━━━━━━━━━━━━━━━━━━ 59s 56ms/step - accuracy: 0.6798 - loss: 0.9422 - val_accuracy: 0.7163 - val_loss: 0.8439 - learning_rate: 1.0000e-04
# Epoch 27/70
# 1054/1055 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.6845 - loss: 0.9247
# Epoch 27: val_accuracy improved from 0.71627 to 0.71893, saving model to CNN_model.keras
# 1055/1055 ━━━━━━━━━━━━━━━━━━━━ 59s 56ms/step - accuracy: 0.6845 - loss: 0.9246 - val_accuracy: 0.7189 - val_loss: 0.8332 - learning_rate: 1.0000e-04
# Epoch 28/70
# 1054/1055 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.6983 - loss: 0.8916
# Epoch 28: val_accuracy did not improve from 0.71893
# 1055/1055 ━━━━━━━━━━━━━━━━━━━━ 58s 55ms/step - accuracy: 0.6983 - loss: 0.8917 - val_accuracy: 0.6949 - val_loss: 0.9047 - learning_rate: 1.0000e-04
# Epoch 29/70
# 1054/1055 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.6961 - loss: 0.8966
# Epoch 29: val_accuracy improved from 0.71893 to 0.72107, saving model to CNN_model.keras
# 1055/1055 ━━━━━━━━━━━━━━━━━━━━ 61s 58ms/step - accuracy: 0.6961 - loss: 0.8966 - val_accuracy: 0.7211 - val_loss: 0.8292 - learning_rate: 1.0000e-04
# Epoch 30/70
# 1054/1055 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.7014 - loss: 0.8866
# Epoch 30: val_accuracy improved from 0.72107 to 0.72907, saving model to CNN_model.keras
# 1055/1055 ━━━━━━━━━━━━━━━━━━━━ 64s 60ms/step - accuracy: 0.7014 - loss: 0.8866 - val_accuracy: 0.7291 - val_loss: 0.8145 - learning_rate: 1.0000e-04
# Epoch 31/70
# 1054/1055 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.7098 - loss: 0.8629
# Epoch 31: val_accuracy did not improve from 0.72907
# 1055/1055 ━━━━━━━━━━━━━━━━━━━━ 63s 60ms/step - accuracy: 0.7098 - loss: 0.8629 - val_accuracy: 0.7291 - val_loss: 0.8189 - learning_rate: 1.0000e-04
# Epoch 32/70
# 1054/1055 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.7096 - loss: 0.8545
# Epoch 32: val_accuracy did not improve from 0.72907
# 1055/1055 ━━━━━━━━━━━━━━━━━━━━ 62s 59ms/step - accuracy: 0.7096 - loss: 0.8545 - val_accuracy: 0.7275 - val_loss: 0.8028 - learning_rate: 1.0000e-04
# Epoch 33/70
# 1054/1055 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.7120 - loss: 0.8513
# Epoch 33: val_accuracy did not improve from 0.72907
# 1055/1055 ━━━━━━━━━━━━━━━━━━━━ 67s 63ms/step - accuracy: 0.7120 - loss: 0.8513 - val_accuracy: 0.7227 - val_loss: 0.8275 - learning_rate: 1.0000e-04
# Epoch 34/70
# 1054/1055 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.7046 - loss: 0.8540
# Epoch 34: val_accuracy did not improve from 0.72907
# 1055/1055 ━━━━━━━━━━━━━━━━━━━━ 65s 62ms/step - accuracy: 0.7046 - loss: 0.8540 - val_accuracy: 0.7061 - val_loss: 0.8855 - learning_rate: 1.0000e-04
# Epoch 35/70
# 1054/1055 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.7166 - loss: 0.8364
# Epoch 35: val_accuracy did not improve from 0.72907
# 1055/1055 ━━━━━━━━━━━━━━━━━━━━ 60s 57ms/step - accuracy: 0.7166 - loss: 0.8364 - val_accuracy: 0.7269 - val_loss: 0.8078 - learning_rate: 1.0000e-04
# Epoch 36/70
# 1054/1055 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.7229 - loss: 0.8144
# Epoch 36: val_accuracy did not improve from 0.72907
# 1055/1055 ━━━━━━━━━━━━━━━━━━━━ 60s 57ms/step - accuracy: 0.7229 - loss: 0.8144 - val_accuracy: 0.7216 - val_loss: 0.8354 - learning_rate: 1.0000e-04
# Epoch 37/70
# 1054/1055 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.7126 - loss: 0.8259
# Epoch 37: val_accuracy did not improve from 0.72907
# 1055/1055 ━━━━━━━━━━━━━━━━━━━━ 60s 57ms/step - accuracy: 0.7127 - loss: 0.8259 - val_accuracy: 0.7051 - val_loss: 0.8539 - learning_rate: 1.0000e-04
# Epoch 38/70
# 1054/1055 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.7330 - loss: 0.8079
# Epoch 38: val_accuracy did not improve from 0.72907
# 1055/1055 ━━━━━━━━━━━━━━━━━━━━ 59s 56ms/step - accuracy: 0.7330 - loss: 0.8079 - val_accuracy: 0.7253 - val_loss: 0.8122 - learning_rate: 1.0000e-04
# Epoch 39/70
# 1054/1055 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.7340 - loss: 0.7895
# Epoch 39: val_accuracy did not improve from 0.72907
# 1055/1055 ━━━━━━━━━━━━━━━━━━━━ 60s 56ms/step - accuracy: 0.7340 - loss: 0.7895 - val_accuracy: 0.7141 - val_loss: 0.8419 - learning_rate: 1.0000e-04
# Epoch 40/70
# 1054/1055 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.7222 - loss: 0.8073
# Epoch 40: val_accuracy did not improve from 0.72907
#
# Epoch 40: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-06.
# 1055/1055 ━━━━━━━━━━━━━━━━━━━━ 59s 56ms/step - accuracy: 0.7222 - loss: 0.8073 - val_accuracy: 0.7035 - val_loss: 0.8771 - learning_rate: 1.0000e-04
# Epoch 41/70
# 1054/1055 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.7367 - loss: 0.7788
# Epoch 41: val_accuracy improved from 0.72907 to 0.74667, saving model to CNN_model.keras
# 1055/1055 ━━━━━━━━━━━━━━━━━━━━ 61s 58ms/step - accuracy: 0.7367 - loss: 0.7787 - val_accuracy: 0.7467 - val_loss: 0.7421 - learning_rate: 1.0000e-05
# Epoch 42/70
# 1054/1055 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.7532 - loss: 0.7348
# Epoch 42: val_accuracy did not improve from 0.74667
# 1055/1055 ━━━━━━━━━━━━━━━━━━━━ 59s 56ms/step - accuracy: 0.7532 - loss: 0.7347 - val_accuracy: 0.7435 - val_loss: 0.7488 - learning_rate: 1.0000e-05
# Epoch 43/70
# 1054/1055 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.7553 - loss: 0.7226
# Epoch 43: val_accuracy improved from 0.74667 to 0.74720, saving model to CNN_model.keras
# 1055/1055 ━━━━━━━━━━━━━━━━━━━━ 61s 58ms/step - accuracy: 0.7553 - loss: 0.7226 - val_accuracy: 0.7472 - val_loss: 0.7352 - learning_rate: 1.0000e-05
# Epoch 44/70
# 1054/1055 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.7552 - loss: 0.7090
# Epoch 44: val_accuracy did not improve from 0.74720
# 1055/1055 ━━━━━━━━━━━━━━━━━━━━ 59s 56ms/step - accuracy: 0.7552 - loss: 0.7091 - val_accuracy: 0.7413 - val_loss: 0.7363 - learning_rate: 1.0000e-05
# Epoch 45/70
# 1054/1055 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.7588 - loss: 0.6984
# Epoch 45: val_accuracy improved from 0.74720 to 0.74987, saving model to CNN_model.keras
# 1055/1055 ━━━━━━━━━━━━━━━━━━━━ 61s 58ms/step - accuracy: 0.7588 - loss: 0.6984 - val_accuracy: 0.7499 - val_loss: 0.7348 - learning_rate: 1.0000e-05
# Epoch 46/70
# 1054/1055 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.7553 - loss: 0.7153
# Epoch 46: val_accuracy did not improve from 0.74987
# 1055/1055 ━━━━━━━━━━━━━━━━━━━━ 59s 56ms/step - accuracy: 0.7553 - loss: 0.7152 - val_accuracy: 0.7451 - val_loss: 0.7287 - learning_rate: 1.0000e-05
# Epoch 47/70
# 1054/1055 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.7679 - loss: 0.6886
# Epoch 47: val_accuracy did not improve from 0.74987
# 1055/1055 ━━━━━━━━━━━━━━━━━━━━ 59s 56ms/step - accuracy: 0.7678 - loss: 0.6886 - val_accuracy: 0.7483 - val_loss: 0.7259 - learning_rate: 1.0000e-05
# Epoch 48/70
# 1054/1055 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.7632 - loss: 0.6888
# Epoch 48: val_accuracy improved from 0.74987 to 0.75040, saving model to CNN_model.keras
# 1055/1055 ━━━━━━━━━━━━━━━━━━━━ 60s 57ms/step - accuracy: 0.7632 - loss: 0.6888 - val_accuracy: 0.7504 - val_loss: 0.7272 - learning_rate: 1.0000e-05
# Epoch 49/70
# 1054/1055 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.7592 - loss: 0.6934
# Epoch 49: val_accuracy improved from 0.75040 to 0.75467, saving model to CNN_model.keras
# 1055/1055 ━━━━━━━━━━━━━━━━━━━━ 60s 57ms/step - accuracy: 0.7592 - loss: 0.6934 - val_accuracy: 0.7547 - val_loss: 0.7228 - learning_rate: 1.0000e-05
# Epoch 50/70
# 1054/1055 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.7692 - loss: 0.6730
# Epoch 50: val_accuracy did not improve from 0.75467
# 1055/1055 ━━━━━━━━━━━━━━━━━━━━ 59s 56ms/step - accuracy: 0.7692 - loss: 0.6730 - val_accuracy: 0.7520 - val_loss: 0.7227 - learning_rate: 1.0000e-05
# Epoch 51/70
# 1054/1055 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.7592 - loss: 0.6968
# Epoch 51: val_accuracy did not improve from 0.75467
# 1055/1055 ━━━━━━━━━━━━━━━━━━━━ 59s 56ms/step - accuracy: 0.7592 - loss: 0.6968 - val_accuracy: 0.7509 - val_loss: 0.7253 - learning_rate: 1.0000e-05
# Epoch 52/70
# 1054/1055 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.7725 - loss: 0.6597
# Epoch 52: val_accuracy did not improve from 0.75467
# 1055/1055 ━━━━━━━━━━━━━━━━━━━━ 59s 56ms/step - accuracy: 0.7725 - loss: 0.6597 - val_accuracy: 0.7509 - val_loss: 0.7282 - learning_rate: 1.0000e-05
# Epoch 53/70
# 1054/1055 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.7734 - loss: 0.6662
# Epoch 53: val_accuracy did not improve from 0.75467
# 1055/1055 ━━━━━━━━━━━━━━━━━━━━ 61s 58ms/step - accuracy: 0.7734 - loss: 0.6662 - val_accuracy: 0.7499 - val_loss: 0.7234 - learning_rate: 1.0000e-05
# Epoch 54/70
# 1054/1055 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.7679 - loss: 0.6749
# Epoch 54: val_accuracy did not improve from 0.75467
# 1055/1055 ━━━━━━━━━━━━━━━━━━━━ 61s 58ms/step - accuracy: 0.7679 - loss: 0.6749 - val_accuracy: 0.7547 - val_loss: 0.7243 - learning_rate: 1.0000e-05
# Epoch 55/70
# 1054/1055 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.7730 - loss: 0.6462
# Epoch 55: val_accuracy did not improve from 0.75467
# 1055/1055 ━━━━━━━━━━━━━━━━━━━━ 61s 58ms/step - accuracy: 0.7730 - loss: 0.6462 - val_accuracy: 0.7520 - val_loss: 0.7182 - learning_rate: 1.0000e-05
# Epoch 56/70
# 1054/1055 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.7609 - loss: 0.6819
# Epoch 56: val_accuracy did not improve from 0.75467
# 1055/1055 ━━━━━━━━━━━━━━━━━━━━ 60s 57ms/step - accuracy: 0.7609 - loss: 0.6818 - val_accuracy: 0.7504 - val_loss: 0.7177 - learning_rate: 1.0000e-05
# Epoch 57/70
# 1054/1055 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.7734 - loss: 0.6671
# Epoch 57: val_accuracy improved from 0.75467 to 0.75573, saving model to CNN_model.keras
# 1055/1055 ━━━━━━━━━━━━━━━━━━━━ 61s 58ms/step - accuracy: 0.7734 - loss: 0.6671 - val_accuracy: 0.7557 - val_loss: 0.7192 - learning_rate: 1.0000e-05
# Epoch 58/70
# 1054/1055 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.7688 - loss: 0.6666
# Epoch 58: val_accuracy did not improve from 0.75573
# 1055/1055 ━━━━━━━━━━━━━━━━━━━━ 59s 56ms/step - accuracy: 0.7688 - loss: 0.6666 - val_accuracy: 0.7547 - val_loss: 0.7179 - learning_rate: 1.0000e-05
# Epoch 59/70
# 1054/1055 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.7748 - loss: 0.6585
# Epoch 59: val_accuracy improved from 0.75573 to 0.75680, saving model to CNN_model.keras
# 1055/1055 ━━━━━━━━━━━━━━━━━━━━ 60s 57ms/step - accuracy: 0.7748 - loss: 0.6585 - val_accuracy: 0.7568 - val_loss: 0.7227 - learning_rate: 1.0000e-05
# Epoch 60/70
# 1054/1055 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.7805 - loss: 0.6570
# Epoch 60: val_accuracy improved from 0.75680 to 0.75787, saving model to CNN_model.keras
# 1055/1055 ━━━━━━━━━━━━━━━━━━━━ 60s 57ms/step - accuracy: 0.7805 - loss: 0.6570 - val_accuracy: 0.7579 - val_loss: 0.7164 - learning_rate: 1.0000e-05
# Epoch 61/70
# 1054/1055 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.7816 - loss: 0.6388
# Epoch 61: val_accuracy did not improve from 0.75787
# 1055/1055 ━━━━━━━━━━━━━━━━━━━━ 60s 57ms/step - accuracy: 0.7816 - loss: 0.6388 - val_accuracy: 0.7552 - val_loss: 0.7229 - learning_rate: 1.0000e-05
# Epoch 62/70
# 1054/1055 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.7694 - loss: 0.6712
# Epoch 62: val_accuracy did not improve from 0.75787
# 1055/1055 ━━━━━━━━━━━━━━━━━━━━ 60s 57ms/step - accuracy: 0.7694 - loss: 0.6712 - val_accuracy: 0.7509 - val_loss: 0.7211 - learning_rate: 1.0000e-05
# Epoch 63/70
# 1054/1055 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.7731 - loss: 0.6546
# Epoch 63: val_accuracy did not improve from 0.75787
# 1055/1055 ━━━━━━━━━━━━━━━━━━━━ 60s 56ms/step - accuracy: 0.7731 - loss: 0.6546 - val_accuracy: 0.7568 - val_loss: 0.7169 - learning_rate: 1.0000e-05
# Epoch 64/70
# 1054/1055 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.7810 - loss: 0.6396
# Epoch 64: val_accuracy did not improve from 0.75787
# 1055/1055 ━━━━━━━━━━━━━━━━━━━━ 60s 57ms/step - accuracy: 0.7810 - loss: 0.6396 - val_accuracy: 0.7563 - val_loss: 0.7195 - learning_rate: 1.0000e-05
# Epoch 65/70
# 1054/1055 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.7784 - loss: 0.6426
# Epoch 65: val_accuracy did not improve from 0.75787
# 1055/1055 ━━━━━━━━━━━━━━━━━━━━ 59s 56ms/step - accuracy: 0.7784 - loss: 0.6426 - val_accuracy: 0.7563 - val_loss: 0.7261 - learning_rate: 1.0000e-05
# Epoch 66/70
# 1054/1055 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.7779 - loss: 0.6475
# Epoch 66: val_accuracy improved from 0.75787 to 0.75893, saving model to CNN_model.keras
# 1055/1055 ━━━━━━━━━━━━━━━━━━━━ 60s 57ms/step - accuracy: 0.7779 - loss: 0.6475 - val_accuracy: 0.7589 - val_loss: 0.7146 - learning_rate: 1.0000e-05
# Epoch 67/70
# 1054/1055 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.7820 - loss: 0.6406
# Epoch 67: val_accuracy did not improve from 0.75893
# 1055/1055 ━━━━━━━━━━━━━━━━━━━━ 58s 55ms/step - accuracy: 0.7820 - loss: 0.6406 - val_accuracy: 0.7573 - val_loss: 0.7110 - learning_rate: 1.0000e-05
# Epoch 68/70
# 1055/1055 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.7791 - loss: 0.6345
# Epoch 68: val_accuracy improved from 0.75893 to 0.75947, saving model to CNN_model.keras
# 1055/1055 ━━━━━━━━━━━━━━━━━━━━ 60s 57ms/step - accuracy: 0.7791 - loss: 0.6345 - val_accuracy: 0.7595 - val_loss: 0.7077 - learning_rate: 1.0000e-05
# Epoch 69/70
# 1054/1055 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.7837 - loss: 0.6247
# Epoch 69: val_accuracy did not improve from 0.75947
# 1055/1055 ━━━━━━━━━━━━━━━━━━━━ 58s 55ms/step - accuracy: 0.7837 - loss: 0.6247 - val_accuracy: 0.7589 - val_loss: 0.7111 - learning_rate: 1.0000e-05
# Epoch 70/70
# 1054/1055 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.7928 - loss: 0.6176
# Epoch 70: val_accuracy improved from 0.75947 to 0.76000, saving model to CNN_model.keras
# 1055/1055 ━━━━━━━━━━━━━━━━━━━━ 60s 57ms/step - accuracy: 0.7928 - loss: 0.6176 - val_accuracy: 0.7600 - val_loss: 0.7141 - learning_rate: 1.0000e-05
# Best validation model: epoch 70  - val_accuracy 0.7599999904632568

# %% [markdown]
# - Training time: ~1h
# - GPU: KAGGLE T4
# - Best validation model: Epoch 17 - Validation accuracy: 0.6011

# %%
# Create a figure with two subplots
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 5))

# --- Plot 1: Model Accuracy ---
ax1.plot(h1.history['accuracy'])
ax1.plot(h1.history['val_accuracy'])
ax1.set_title('Model Accuracy')
ax1.set_ylabel('Accuracy')
ax1.set_xlabel('Epoch')
ax1.legend(['Train', 'Validation'], loc='upper left')
ax1.grid(True)

# --- Plot 2: Model Loss ---
ax2.plot(h1.history['loss'])
ax2.plot(h1.history['val_loss'])
ax2.set_title('Model Loss')
ax2.set_ylabel('Loss')
ax2.set_xlabel('Epoch')
ax2.legend(['Train', 'Validation'], loc='upper right')
ax2.grid(True)

# Show the plots
plt.tight_layout()
plt.show()
fig.savefig('training_plots.png')

# --- Your code for printing the best model can go here ---
best_idx = int(np.argmax(h1.history['val_accuracy']))
best_value = np.max(h1.history['val_accuracy'])
print('Best validation model: epoch ' + str(best_idx+1), ' - val_accuracy ' + str(best_value))
# Out:
# Best validation model: epoch 70  - val_accuracy 0.7599999904632568

# %% [markdown]
# ### 2.3 Validation

# %%
def draw_confusion_matrix(cm, categories):
    # Draw confusion matrix
    fig = plt.figure(figsize=[6.4*pow(len(categories), 0.5), 4.8*pow(len(categories), 0.5)])
    ax = fig.add_subplot(111)
    cm = cm.astype('float') / np.maximum(cm.sum(axis=1)[:, np.newaxis], np.finfo(np.float64).eps)
    im = ax.imshow(cm, interpolation='nearest', cmap=plt.colormaps['Blues'])
    ax.figure.colorbar(im, ax=ax)
    ax.set(xticks=np.arange(cm.shape[1]), yticks=np.arange(cm.shape[0]), xticklabels=list(categories.values()), yticklabels=list(categories.values()), ylabel='Annotation', xlabel='Prediction')
    # Rotate the tick labels and set their alignment
    plt.setp(ax.get_xticklabels(), rotation=45, ha="right", rotation_mode="anchor")
    # Loop over data dimensions and create text annotations
    thresh = cm.max() / 2.0
    for i in range(cm.shape[0]):
        for j in range(cm.shape[1]):
            ax.text(j, i, format(cm[i, j], '.2f'), ha="center", va="center", color="white" if cm[i, j] > thresh else "black", fontsize=int(20-pow(len(categories), 0.5)))
    fig.tight_layout()
    plt.show()

    # Save confusion matrix figure
    fig.savefig('confusion_matrix.png')

# %%
model.load_weights(MODEL_NAME)
y_true, y_pred = [], []
for ann in val2:
    # Load image
    image = load_geoimage(ann.filename)
    for obj_pred in ann.objects:
        # Generate prediction
        warped_image = np.expand_dims(image, 0)
        predictions = model.predict(warped_image, verbose=0)
        # Save prediction
        pred_category = list(categories.values())[np.argmax(predictions)]
        pred_score = np.max(predictions)
        y_true.append(obj_pred.category)
        y_pred.append(pred_category)

# %%
# Compute the confusion matrix
cm = confusion_matrix(y_true, y_pred, labels=list(categories.values()))
draw_confusion_matrix(cm, categories)

# %%
# Compute the accuracy
correct_samples_class = np.diag(cm).astype(float)
total_samples_class = np.sum(cm, axis=1).astype(float)
total_predicts_class = np.sum(cm, axis=0).astype(float)
print('Mean Accuracy: %.3f%%' % (np.sum(correct_samples_class) / np.sum(total_samples_class) * 100))
acc = correct_samples_class / np.maximum(total_samples_class, np.finfo(np.float64).eps)
print('Mean Recall: %.3f%%' % (acc.mean() * 100))
acc = correct_samples_class / np.maximum(total_predicts_class, np.finfo(np.float64).eps)
print('Mean Precision: %.3f%%' % (acc.mean() * 100))
for idx in range(len(categories)):
    # True/False Positives (TP/FP) refer to the number of predicted positives that were correct/incorrect.
    # True/False Negatives (TN/FN) refer to the number of predicted negatives that were correct/incorrect.
    tp = cm[idx, idx]
    fp = sum(cm[:, idx]) - tp
    fn = sum(cm[idx, :]) - tp
    tn = sum(np.delete(sum(cm) - cm[idx, :], idx))
    # True Positive Rate: proportion of real positive cases that were correctly predicted as positive.
    recall = tp / np.maximum(tp+fn, np.finfo(np.float64).eps)
    # Precision: proportion of predicted positive cases that were truly real positives.
    precision = tp / np.maximum(tp+fp, np.finfo(np.float64).eps)
    # True Negative Rate: proportion of real negative cases that were correctly predicted as negative.
    specificity = tn / np.maximum(tn+fp, np.finfo(np.float64).eps)
    # Dice coefficient refers to two times the intersection of two sets divided by the sum of their areas.
    # Dice = 2 |A∩B| / (|A|+|B|) = 2 TP / (2 TP + FP + FN)
    f1_score = 2 * ((precision * recall) / np.maximum(precision+recall, np.finfo(np.float64).eps))
    print('> %s: Recall: %.3f%% Precision: %.3f%% Specificity: %.3f%% Dice: %.3f%%' % (list(categories.values())[idx], recall*100, precision*100, specificity*100, f1_score*100))
# Out:
# Mean Accuracy: 76.000%
# Mean Recall: 78.109%
# Mean Precision: 78.371%
# > Cargo plane: Recall: 90.625% Precision: 98.305% Specificity: 99.945% Dice: 94.309%
# > Small car: Recall: 89.458% Precision: 79.625% Specificity: 95.075% Dice: 84.255%
# > Bus: Recall: 64.972% Precision: 56.373% Specificity: 94.759% Dice: 60.367%
# > Truck: Recall: 31.674% Precision: 44.025% Specificity: 94.619% Dice: 36.842%
# > Motorboat: Recall: 82.243% Precision: 87.129% Specificity: 99.265% Dice: 84.615%
# > Fishing vessel: Recall: 84.507% Precision: 75.949% Specificity: 98.947% Dice: 80.000%
# > Dump truck: Recall: 63.710% Precision: 64.228% Specificity: 97.487% Dice: 63.968%
# > Excavator: Recall: 84.810% Precision: 83.750% Specificity: 99.276% Dice: 84.277%
# > Building: Recall: 89.415% Precision: 88.674% Specificity: 97.296% Dice: 89.043%
# > Helipad: Recall: 90.909% Precision: 90.909% Specificity: 99.946% Dice: 90.909%
# > Storage tank: Recall: 82.313% Precision: 88.971% Specificity: 99.132% Dice: 85.512%
# > Shipping container: Recall: 73.684% Precision: 70.886% Specificity: 97.330% Dice: 72.258%
# > Pylon: Recall: 87.097% Precision: 90.000% Specificity: 99.837% Dice: 88.525%

# %% [markdown]
# ### 2.4 Testing

# %%
anns = []
i = 0
for (dirpath, dirnames, filenames) in os.walk('/kaggle/input/xview-dataset/xview_recognition/xview_test/'):
    for filename in filenames:
        image = GenericImage(dirpath + '/' + filename)
        image.tile = np.array([0, 0, 224, 224])
        obj = GenericObject()
        obj.bb = (0, 0, 224, 224)
        obj.category = dirpath[dirpath.rfind('/')+1:]
        image.add_object(obj)
        anns.append(image)
print('Number of testing images: ' + str(len(anns)))
# Out:
# Number of testing images: 0

# %%
model.load_weights(MODEL_NAME)
predictions_data = {"images": {}, "annotations": {}}

for idx, ann in enumerate(anns):
    image_data = {"image_id": ann.filename.split('/')[-1], "filename": ann.filename, "width": int(ann.tile[2]), "height": int(ann.tile[3])}
    predictions_data["images"][idx] = image_data
    # Load image
    image = load_geoimage("/".join(ann.filename.split('/')[-3:]))
    for obj_pred in ann.objects:
        # Generate prediction
        warped_image = np.expand_dims(image, 0)
        predictions = model.predict(warped_image, verbose=0)
        # Save prediction
        pred_category = list(categories.values())[np.argmax(predictions)]
        pred_score = np.max(predictions)
        annotation_data = {"image_id": ann.filename.split('/')[-1], "category_id": pred_category, "bbox": [int(x) for x in obj_pred.bb]}
        predictions_data["annotations"][idx] = annotation_data

# %%
with open("prediction.json", "w") as outfile:
    json.dump(predictions_data, outfile)
